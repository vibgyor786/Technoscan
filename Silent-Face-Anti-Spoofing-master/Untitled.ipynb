# %%
# import cv2
# from test import test






import os
import cv2
import numpy as np
import argparse
import warnings
import time

from src.anti_spoof_predict import AntiSpoofPredict
from src.generate_patches import CropImage
from src.utility import parse_model_name
warnings.filterwarnings('ignore')

video_capture = cv2.VideoCapture(0)

# SAMPLE_IMAGE_PATH = "./images/sample/"


# 因为安卓端APK获取的视频流宽高比为3:4,为了与之一致，所以将宽高比限制为3:4
def check_image(image):
    height, width, channel = image.shape
    if width/height != 3/4:
        print("Image is not appropriate!!!\nHeight/Width should be 4/3.")
        return False
    else:
        return True


def test(image, model_dir, device_id):
    model_test = AntiSpoofPredict(device_id)
    image_cropper = CropImage()
    # image = cv2.imread(SAMPLE_IMAGE_PATH + image_name)
    image=cv2.resize(image,(int(image.shape[0]*3/4),image.shape[0]))
    result = check_image(image)
    if result is False:
        return
    image_bbox = model_test.get_bbox(image)
    prediction = np.zeros((1, 3))
    test_speed = 0
    # sum the prediction from single model's result
    for model_name in os.listdir(model_dir):
        h_input, w_input, model_type, scale = parse_model_name(model_name)
        param = {
            "org_img": image,
            "bbox": image_bbox,
            "scale": scale,
            "out_w": w_input,
            "out_h": h_input,
            "crop": True,
        }
        if scale is None:
            param["crop"] = False
        img = image_cropper.crop(**param)
        start = time.time()
        prediction += model_test.predict(img, os.path.join(model_dir, model_name))
        test_speed += time.time()-start

    # draw result of prediction
    label = np.argmax(prediction)
    value = prediction[0][label]/2
    
    print("Prediction cost {:.2f} s".format(test_speed))
    return label





while True:
        ret, img = video_capture.read()
        label=test(
            image=img,
            model_dir=r"C:\Users\vibgyor\Desktop\Silent-Face-Anti-Spoofing-master\Silent-Face-Anti-Spoofing-master\resources\anti_spoof_models",
            device_id=0
        )
        print(label)
        # cv2.putText(label)
        cv2.imshow("face Detection", img)
        if cv2.waitKey(1)==13:
            break
video_capture.release()
cv2.destroyAllWindows()
# Out:
# Prediction cost 0.15 s
# 2
# Prediction cost 0.13 s
# 2
# Prediction cost 0.14 s
# 2
# Prediction cost 0.13 s
# 1
# Prediction cost 0.14 s
# 1
# Prediction cost 0.18 s
# 1
# Prediction cost 0.17 s
# 1
# Prediction cost 0.27 s
# 1
# Prediction cost 0.16 s
# 1
# Prediction cost 0.15 s
# 1
# Prediction cost 0.16 s
# 1
# Prediction cost 0.15 s
# 1
# Prediction cost 0.17 s
# 1
# Prediction cost 0.15 s
# 1
# Prediction cost 0.16 s
# 1
# Prediction cost 0.18 s
# 1
# Prediction cost 0.27 s
# 1
# Prediction cost 0.18 s
# 1
# Prediction cost 0.18 s
# 1
# Prediction cost 0.17 s
# 1
# Prediction cost 0.15 s
# 1
# Prediction cost 0.17 s
# 1
# Prediction cost 0.19 s
# 1
# Prediction cost 0.16 s
# 1
# Prediction cost 0.18 s
# 1
# Prediction cost 0.27 s
# 1
# Prediction cost 0.20 s
# 1
# Prediction cost 0.18 s
# 1
# Prediction cost 0.17 s
# 1
# Prediction cost 0.18 s
# 1
# Prediction cost 0.16 s
# 1
# Prediction cost 0.17 s
# 1
# Prediction cost 0.17 s
# 1
# Prediction cost 0.28 s
# 1
# ...
